# %% [markdown]
# #In this project We are going to analyze the Airbnb New York dataset
# # New York City Airbnb Open Data
# #Airbnb is a paid community platform for renting and booking private accommodation founded in 2008. Airbnb allows individuals to rent all or part of their own home as extra accommodation.

# %%
##firstly we import all the modules
import warnings
warnings.filterwarnings('ignore')
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/dataset/AB_NYC_2019.csv')
df_copy = df.copy()
df.head()
# Out:
#      id  ... availability_365
# 0  2539  ...              365
# 1  2595  ...              355
# 2  3647  ...              365
# 3  3831  ...              194
# 4  5022  ...                0
#
# [5 rows x 16 columns]

# %% [markdown]
# #The dataset contains the following variables:
#
#
# 1.   id (int): identification number
# 2.   name (string): name of the apartment
# 3.   host_id (int): identification number of the host
# 4.   neighbourhood_group (String): neighbourhood group. Four groups (Bronx,Queens,Manhattan,Staten Island,Brooklyn)
# 5.   latitude (Float): Latitude of the apartment
# 6.   longitude (Float): Longitude of the apartment
# 7.   room_type (String): Type of room
# 8.   price (int): Price per night
# 9.   minimum_nights (int): Minimum nights to stay in the apartment
# 10.  number_of_reviews (String): Number of reviews of the apartment
# 11.  availability_365 (int): Number of available days of this apartment during the year.

# %%
plt.figure(figsize=(12, 8))
g=sns.scatterplot(df.longitude,df.latitude,hue=df.neighbourhood_group)
# g.legend_.remove()
plt.box(False)
plt.axis('off');
plt.title('Mapping of all the listings in Newyork City');

# %% [markdown]
# <center><image src='https://upload.wikimedia.org/wikipedia/commons/3/34/5_Boroughs_Labels_New_York_City_Map.svg' width=600 height=600></center>

# %% [markdown]
# # EDA

# %% [markdown]
# ### Number of Rows & Number of Columns

# %%
print(f'The Dataset contains {df.shape[0]} rows & {df.shape[1]} columns')
# Out:
# The Dataset contains 48895 rows & 16 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB

# %% [markdown]
# ### Numerical Data Columns

# %%
print(df.select_dtypes(exclude='O').columns)
# Out:
# Index(['id', 'host_id', 'latitude', 'longitude', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %% [markdown]
# ### Categorical Data Columns

# %%
print(df.select_dtypes(include='O').columns)
# Out:
# Index(['name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'room_type', 'last_review'],
#       dtype='object')

# %% [markdown]
# **Some of the columns are not required for Regression Analysis, so we will drop those columns**

# %%
df = df.drop(['last_review', 'host_name', 'name', 'id', 'host_id'], axis=1)

# %% [markdown]
# ### Checking For Null values

# %%
df.isnull().sum()
# Out:
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Replacing all the values in the reviews_per_month column to 0

df['reviews_per_month'].fillna(0, inplace = True)

# %%
df.isnull().sum()
# Out:
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %% [markdown]
# **There are no null values present in the Database**

# %%
sns.distplot(a=df['price']);

# %% [markdown]
# **We can see that the Distribution for House Prices is heavily skewed to the right, with House prices upto 10000$**

# %%
Q1 = df['price'].quantile(0.25)
Q3 = df['price'].quantile(0.75)
IQR = Q3 - Q1
Q3+IQR*1.5
# Out:
# 334.0

# %%
temp_df = df[df['price'] < (Q3+IQR*1.5)]
sns.FacetGrid(temp_df, hue='room_type', size=4.5).map(sns.distplot, 'price', kde=False, bins=20).add_legend();

# %%
print(f"The Mean of House prices is {round(df['price'].mean())}$")
print(f"The Median of House prices is {round(df['price'].median())}$")
# Out:
# The Mean of House prices is 153$
# The Median of House prices is 106$

# %%
plt.figure(figsize=(15, 4))

sns.boxplot(x=df['price'])

plt.title('Box-Plot - House Rental Price');

# %%
df[df['price'] > (Q3+IQR*1.5)].shape[0]
# Out:
# 2972

# %% [markdown]
# **There are 2972 houses above the Upper Extreme of Box**

# %% [markdown]
# **According to the Box-Plot; listings above price of $334 should be considered as outliers**

# %% [markdown]
# **There are some Houses, listed with price of 0$, we will drop those columns as it is unlikely that people are letting others to rent their houses for Free**

# %%
df = df[df['price'] != 0]

# %% [markdown]
# ### Most Common Renting Price for the Houses

# %%
plt.figure(figsize=(10, 4))

df['price'].value_counts().nlargest(12).plot(kind='bar')

plt.xticks(rotation=0);
plt.title('Most Common Renting Price for the Houses');
plt.ylabel('Price in Dollars');

# %% [markdown]
# **here we can see that most common price is 100 and 150***

# %% [markdown]
# ### Average Price for Different room Types

# %%
plt.figure(figsize=(6, 4))

df.groupby('room_type')['price'].mean().plot(kind='bar')

plt.xticks(rotation=0);
plt.ylabel('Price in Dollars');
plt.title('Average Price for Different Room Types');

# %% [markdown]
# **We can see that the Entire Apartments cost high on Average than Private Rooms or Shared Rooms**

# %% [markdown]
# ### Most Commom Room Types Preferred for Renting

# %%
sns.countplot(df['room_type'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,5)
plt.title('Count Plot - Room Type');

# %% [markdown]
# **We can see that there are more listings for Entire Homes or Private Rooms**

# %% [markdown]
# # deven

# %%
df['room_type'].value_counts().plot(kind='pie', autopct='%.2f',fontsize=12,figsize=(5,5))

# %% [markdown]
# **We can see that Entire home and Private room Having high frequncy compare to Shared room**

# %%
temp_df = pd.DataFrame(df.groupby(['minimum_nights', 'room_type'])['price'].count()[:30])
temp_df.reset_index(inplace=True)


sns.catplot(x='minimum_nights', y='price', hue='room_type', data=temp_df, kind='bar', aspect=2);

# %% [markdown]
# **Observations**
#
# - We can see that Private rooms have more 1 minimun night requirements than, Entire Apartments
# - People who rent their Entire apartments prefer having minimum 2 or 3 night stay
# - Entire Apartments have more 2 or 3 nights requirements than Private rooms

# %% [markdown]
# ### Minimum nights Requirements

# %%
df['minimum_nights'].value_counts()[:10].plot(kind='bar')

plt.xticks(rotation=0);
plt.ylabel('Count');
plt.title('CountPlot - Minimum nights');

# %% [markdown]
# **Most minimum night requirements listed are 1, 2 or 3 nights**

# %% [markdown]
# ### Cities with Most Listings

# %%
sns.countplot(df['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,5)
plt.title('Most Number of Listings By Neighbourhood Group');

# %% [markdown]
# **Manhattan has the most listings for renal homes followed by Brooklyn**

# %% [markdown]
# # Most costly Cities to Rent Rooms

# %%
df.groupby('neighbourhood_group').mean()['price'].plot(kind='bar')

plt.xticks(rotation=0);

# %% [markdown]
# **Manhattan is an important commercial, financial, and cultural center of Newyork, so it makes sense that average cost of renting rooms is high in Manhattan than other areas**

# %%
# Neighbourhood with most number of listings and their median renting cost

# %%
df[df['neighbourhood_group'] == 'Manhattan'].groupby('neighbourhood').agg(['median', 'count'])['price'].nlargest(10, columns='count').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row0_col0 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row1_col0 {
#             background-color:  #f5523a;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row1_col1 {
#             background-color:  #f0402f;
#             color:  #f1f1f1;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row2_col0 {
#             background-color:  #da2723;
#             color:  #f1f1f1;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row2_col1 {
#             background-color:  #f14331;
#             color:  #f1f1f1;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row3_col0 {
#             background-color:  #f5523a;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row3_col1 {
#             background-color:  #f75b40;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row4_col0 {
#             background-color:  #f6553c;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row4_col1 {
#             background-color:  #fa6648;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row5_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row5_col1 {
#             background-color:  #fc9474;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row6_col0 {
#             background-color:  #fdcbb6;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row6_col1 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row7_col0 {
#             background-color:  #8e0912;
#             color:  #f1f1f1;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row7_col1 {
#             background-color:  #fee1d3;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row8_col0 {
#             background-color:  #fb6e4e;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row8_col1 {
#             background-color:  #fff4ef;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row9_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >median</th>        <th class="col_heading level0 col1" >count</th>    </tr>    <tr>        <th class="index_name level0" >neighbourhood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row0" class="row_heading level0 row0" >Harlem</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row0_col0" class="data row0 col0" >89.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row0_col1" class="data row0 col1" >2658</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row1" class="row_heading level0 row1" >Upper West Side</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row1_col0" class="data row1 col0" >150.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row1_col1" class="data row1 col1" >1971</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row2" class="row_heading level0 row2" >Hell's Kitchen</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row2_col0" class="data row2 col0" >168.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row2_col1" class="data row2 col1" >1958</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row3" class="row_heading level0 row3" >East Village</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row3_col0" class="data row3 col0" >150.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row3_col1" class="data row3 col1" >1853</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row4" class="row_heading level0 row4" >Upper East Side</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row4_col0" class="data row4 col0" >149.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row4_col1" class="data row4 col1" >1798</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row5" class="row_heading level0 row5" >Midtown</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row5_col0" class="data row5 col0" >210.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row5_col1" class="data row5 col1" >1545</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row6" class="row_heading level0 row6" >East Harlem</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row6_col0" class="data row6 col0" >99.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row6_col1" class="data row6 col1" >1117</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row7" class="row_heading level0 row7" >Chelsea</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row7_col0" class="data row7 col0" >199.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row7_col1" class="data row7 col1" >1113</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row8" class="row_heading level0 row8" >Lower East Side</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row8_col0" class="data row8 col0" >139.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row8_col1" class="data row8 col1" >911</td>
#             </tr>
#             <tr>
#                         <th id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002level0_row9" class="row_heading level0 row9" >Washington Heights</th>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row9_col0" class="data row9 col0" >72.000000</td>
#                         <td id="T_e47c20b6_e8f7_11ea_bc4e_0242ac1c0002row9_col1" class="data row9 col1" >899</td>
#             </tr>
#     </tbody></table>

# %%
df[df['neighbourhood_group'] == 'Brooklyn'].groupby('neighbourhood').agg(['median', 'count'])['price'].nlargest(10, columns='count').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row0_col0 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row1_col0 {
#             background-color:  #fdcdb9;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row1_col1 {
#             background-color:  #840711;
#             color:  #f1f1f1;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row2_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row2_col1 {
#             background-color:  #f44f39;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row3_col0 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row3_col1 {
#             background-color:  #fca78b;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row4_col0 {
#             background-color:  #e12d26;
#             color:  #f1f1f1;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row4_col1 {
#             background-color:  #fdd1be;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row5_col0 {
#             background-color:  #fee7db;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row5_col1 {
#             background-color:  #ffefe8;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row6_col0 {
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row6_col1 {
#             background-color:  #fff2eb;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row7_col0 {
#             background-color:  #fdcdb9;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row7_col1 {
#             background-color:  #fff4ee;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row8_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row8_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row9_col0 {
#             background-color:  #fee0d2;
#             color:  #000000;
#         }    #T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >median</th>        <th class="col_heading level0 col1" >count</th>    </tr>    <tr>        <th class="index_name level0" >neighbourhood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row0" class="row_heading level0 row0" >Williamsburg</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row0_col0" class="data row0 col0" >105.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row0_col1" class="data row0 col1" >3919</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row1" class="row_heading level0 row1" >Bedford-Stuyvesant</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row1_col0" class="data row1 col0" >80.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row1_col1" class="data row1 col1" >3710</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row2" class="row_heading level0 row2" >Bushwick</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row2_col0" class="data row2 col0" >65.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row2_col1" class="data row2 col1" >2462</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row3" class="row_heading level0 row3" >Crown Heights</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row3_col0" class="data row3 col0" >85.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row3_col1" class="data row3 col1" >1564</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row4" class="row_heading level0 row4" >Greenpoint</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row4_col0" class="data row4 col0" >119.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row4_col1" class="data row4 col1" >1114</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row5" class="row_heading level0 row5" >Flatbush</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row5_col0" class="data row5 col0" >72.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row5_col1" class="data row5 col1" >621</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row6" class="row_heading level0 row6" >Clinton Hill</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row6_col0" class="data row6 col0" >120.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row6_col1" class="data row6 col1" >572</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row7" class="row_heading level0 row7" >Prospect-Lefferts Gardens</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row7_col0" class="data row7 col0" >80.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row7_col1" class="data row7 col1" >535</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row8" class="row_heading level0 row8" >Park Slope</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row8_col0" class="data row8 col0" >145.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row8_col1" class="data row8 col1" >506</td>
#             </tr>
#             <tr>
#                         <th id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002level0_row9" class="row_heading level0 row9" >East Flatbush</th>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row9_col0" class="data row9 col0" >75.000000</td>
#                         <td id="T_e488458a_e8f7_11ea_bc4e_0242ac1c0002row9_col1" class="data row9 col1" >500</td>
#             </tr>
#     </tbody></table>

# %%
df[df['neighbourhood_group'] == 'Queens'].groupby('neighbourhood').agg(['median', 'count'])['price'].nlargest(10, columns='count').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row0_col0 {
#             background-color:  #e83429;
#             color:  #f1f1f1;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row1_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row1_col1 {
#             background-color:  #fb6d4d;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row2_col0 {
#             background-color:  #fed9c9;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row2_col1 {
#             background-color:  #fc9e80;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row3_col0 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row3_col1 {
#             background-color:  #fca183;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row4_col0 {
#             background-color:  #fc8a6a;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row4_col1 {
#             background-color:  #fcbca2;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row5_col0 {
#             background-color:  #fb694a;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row5_col1 {
#             background-color:  #fdd2bf;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row6_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row6_col1 {
#             background-color:  #fee9df;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row7_col0 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row7_col1 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row8_col0 {
#             background-color:  #fcb398;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row8_col1 {
#             background-color:  #feeae1;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row9_col0 {
#             background-color:  #fcbfa7;
#             color:  #000000;
#         }    #T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >median</th>        <th class="col_heading level0 col1" >count</th>    </tr>    <tr>        <th class="index_name level0" >neighbourhood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row0" class="row_heading level0 row0" >Astoria</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row0_col0" class="data row0 col0" >85.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row0_col1" class="data row0 col1" >900</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row1" class="row_heading level0 row1" >Long Island City</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row1_col0" class="data row1 col0" >99.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row1_col1" class="data row1 col1" >537</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row2" class="row_heading level0 row2" >Flushing</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row2_col0" class="data row2 col0" >65.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row2_col1" class="data row2 col1" >426</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row3" class="row_heading level0 row3" >Ridgewood</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row3_col0" class="data row3 col0" >60.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row3_col1" class="data row3 col1" >423</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row4" class="row_heading level0 row4" >Sunnyside</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row4_col0" class="data row4 col0" >75.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row4_col1" class="data row4 col1" >363</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row5" class="row_heading level0 row5" >Ditmars Steinway</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row5_col0" class="data row5 col0" >79.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row5_col1" class="data row5 col1" >309</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row6" class="row_heading level0 row6" >Elmhurst</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row6_col0" class="data row6 col0" >59.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row6_col1" class="data row6 col1" >237</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row7" class="row_heading level0 row7" >Woodside</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row7_col0" class="data row7 col0" >60.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row7_col1" class="data row7 col1" >235</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row8" class="row_heading level0 row8" >Jamaica</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row8_col0" class="data row8 col0" >70.000000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row8_col1" class="data row8 col1" >231</td>
#             </tr>
#             <tr>
#                         <th id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002level0_row9" class="row_heading level0 row9" >Jackson Heights</th>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row9_col0" class="data row9 col0" >68.500000</td>
#                         <td id="T_e491dd34_e8f7_11ea_bc4e_0242ac1c0002row9_col1" class="data row9 col1" >186</td>
#             </tr>
#     </tbody></table>

# %%
df[df['neighbourhood_group'] == 'Bronx'].groupby('neighbourhood').agg(['median', 'count'])['price'].nlargest(10, columns='count').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row0_col0 {
#             background-color:  #f44d38;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row1_col0 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row1_col1 {
#             background-color:  #c3161b;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row2_col0 {
#             background-color:  #c5171c;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row2_col1 {
#             background-color:  #ce1a1e;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row3_col0 {
#             background-color:  #d01d1f;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row3_col1 {
#             background-color:  #e02c26;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row4_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row4_col1 {
#             background-color:  #fc997a;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row5_col0 {
#             background-color:  #fdccb8;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row5_col1 {
#             background-color:  #fc997a;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row6_col0 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row6_col1 {
#             background-color:  #fcc3ab;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row7_col0 {
#             background-color:  #fb7c5c;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row7_col1 {
#             background-color:  #fee5d9;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row8_col0 {
#             background-color:  #fc9c7d;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row8_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row9_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >median</th>        <th class="col_heading level0 col1" >count</th>    </tr>    <tr>        <th class="index_name level0" >neighbourhood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row0" class="row_heading level0 row0" >Kingsbridge</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row0_col0" class="data row0 col0" >70.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row0_col1" class="data row0 col1" >70</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row1" class="row_heading level0 row1" >Fordham</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row1_col0" class="data row1 col0" >60.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row1_col1" class="data row1 col1" >63</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row2" class="row_heading level0 row2" >Longwood</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row2_col0" class="data row2 col0" >75.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row2_col1" class="data row2 col1" >62</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row3" class="row_heading level0 row3" >Mott Haven</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row3_col0" class="data row3 col0" >74.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row3_col1" class="data row3 col1" >60</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row4" class="row_heading level0 row4" >Concourse</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row4_col0" class="data row4 col0" >81.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row4_col1" class="data row4 col1" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row5" class="row_heading level0 row5" >Wakefield</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row5_col0" class="data row5 col0" >60.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row5_col1" class="data row5 col1" >50</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row6" class="row_heading level0 row6" >Port Morris</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row6_col0" class="data row6 col0" >62.500000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row6_col1" class="data row6 col1" >46</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row7" class="row_heading level0 row7" >Allerton</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row7_col0" class="data row7 col0" >66.500000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row7_col1" class="data row7 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row8" class="row_heading level0 row8" >Williamsbridge</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row8_col0" class="data row8 col0" >64.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row8_col1" class="data row8 col1" >40</td>
#             </tr>
#             <tr>
#                         <th id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002level0_row9" class="row_heading level0 row9" >Parkchester</th>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row9_col0" class="data row9 col0" >55.000000</td>
#                         <td id="T_e49b233a_e8f7_11ea_bc4e_0242ac1c0002row9_col1" class="data row9 col1" >39</td>
#             </tr>
#     </tbody></table>

# %%
df[df['neighbourhood_group'] == 'Staten Island'].groupby('neighbourhood').agg(['median', 'count'])['price'].nlargest(10, columns='count').style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row0_col1 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row1_col0 {
#             background-color:  #fb7858;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row1_col1 {
#             background-color:  #ad1117;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row2_col0 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row2_col1 {
#             background-color:  #fb7656;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row3_col0 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row3_col1 {
#             background-color:  #fc7f5f;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row4_col0 {
#             background-color:  #fb6c4c;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row4_col1 {
#             background-color:  #fca98c;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row5_col0 {
#             background-color:  #d21f20;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row5_col1 {
#             background-color:  #fcb99f;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row6_col0 {
#             background-color:  #f4503a;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row6_col1 {
#             background-color:  #fcc1a8;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row7_col0 {
#             background-color:  #e53228;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row7_col1 {
#             background-color:  #fed8c7;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row8_col0 {
#             background-color:  #bf151b;
#             color:  #f1f1f1;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row8_col1 {
#             background-color:  #fff1ea;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row9_col0 {
#             background-color:  #fcbba1;
#             color:  #000000;
#         }    #T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row9_col1 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }</style><table id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >median</th>        <th class="col_heading level0 col1" >count</th>    </tr>    <tr>        <th class="index_name level0" >neighbourhood</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row0" class="row_heading level0 row0" >St. George</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row0_col0" class="data row0 col0" >96.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row0_col1" class="data row0 col1" >48</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row1" class="row_heading level0 row1" >Tompkinsville</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row1_col0" class="data row1 col0" >62.500000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row1_col1" class="data row1 col1" >42</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row2" class="row_heading level0 row2" >Stapleton</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row2_col0" class="data row2 col0" >75.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row2_col1" class="data row2 col1" >27</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row3" class="row_heading level0 row3" >Concord</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row3_col0" class="data row3 col0" >34.500000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row3_col1" class="data row3 col1" >26</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row4" class="row_heading level0 row4" >Arrochar</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row4_col0" class="data row4 col0" >65.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row4_col1" class="data row4 col1" >21</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row5" class="row_heading level0 row5" >Randall Manor</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row5_col0" class="data row5 col0" >79.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row5_col1" class="data row5 col1" >19</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row6" class="row_heading level0 row6" >West Brighton</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row6_col0" class="data row6 col0" >69.500000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row6_col1" class="data row6 col1" >18</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row7" class="row_heading level0 row7" >Clifton</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row7_col0" class="data row7 col0" >75.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row7_col1" class="data row7 col1" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row8" class="row_heading level0 row8" >Great Kills</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row8_col0" class="data row8 col0" >83.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row8_col1" class="data row8 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002level0_row9" class="row_heading level0 row9" >Port Richmond</th>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row9_col0" class="data row9 col0" >50.000000</td>
#                         <td id="T_e4a455e0_e8f7_11ea_bc4e_0242ac1c0002row9_col1" class="data row9 col1" >9</td>
#             </tr>
#     </tbody></table>

# %%
df['availability_365'].value_counts()[:10].plot(kind='bar');

# %% [markdown]
# **Observations**
#
# - We can see that many of the listings have an availability set as 0
# - This is due to AIRBNB allows hosts to temporarily set their listing as UNAVAILABLE, and not remove the listing
# - This results in listings that are temporarily unavailable due to host preferences

# %%
df = df[df['price'] < (Q3+IQR*1.5)]

# %%
sns.distplot(a=df['price']);
plt.title('Distribution after Dropping the Outliers');

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True);

# %% [markdown]
# **Observations**
# - **There are no features with a strong correlation with the Target Variables**
# - **Also there is no MultiCollinearity present between the Features**

# %% [markdown]
# #prathmesh

# %%
# classifiy data into categorical and numerical
df_cat = df.select_dtypes(object)
df_num = df.select_dtypes(["int64","float64"])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in df_cat:
    le = LabelEncoder()
    df_cat[col] = le.fit_transform(df_cat[col])
df_cat.head()
# Out:
#    neighbourhood_group  neighbourhood  room_type
# 0                    1            107          1
# 1                    2            126          0
# 2                    2             93          1
# 3                    1             41          0
# 4                    2             61          0

# %%
df_new = pd.concat([df_num, df_cat], axis=1)
df_new.head()
# Out:
#    latitude  longitude  price  ...  neighbourhood_group  neighbourhood  room_type
# 0  40.64749  -73.97237    149  ...                    1            107          1
# 1  40.75362  -73.98377    225  ...                    2            126          0
# 2  40.80902  -73.94190    150  ...                    2             93          1
# 3  40.68514  -73.95976     89  ...                    1             41          0
# 4  40.79851  -73.94399     80  ...                    2             61          0
#
# [5 rows x 11 columns]

# %%
df_mm = df_new.copy()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
columns = df_mm.columns.to_list()
columns.remove('price')

for col in columns:
    mm = MinMaxScaler()
    df_mm[col] = mm.fit_transform(df_mm[[col]])
df_mm.head()
# Out:
#    latitude  longitude  price  ...  neighbourhood_group  neighbourhood  room_type
# 0  0.357393   0.511921    149  ...                 0.25       0.490826        0.5
# 1  0.614199   0.490469    225  ...                 0.50       0.577982        0.0
# 2  0.748252   0.569257    150  ...                 0.50       0.426606        0.5
# 3  0.448496   0.535649     89  ...                 0.25       0.188073        0.0
# 4  0.722820   0.565324     80  ...                 0.50       0.279817        0.0
#
# [5 rows x 11 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %%
X = df_mm.drop("price",axis=1)
y = np.log(df_mm['price'])

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 6))

ax=ax.flatten()

sns.distplot(a=df['price'], ax=ax[0], bins=20);
ax[0].set(title='Distribution after Dropping the Outliers');

sns.distplot(a=y, ax=ax[1], bins=20);
ax[1].set(title='Distribution after Taking the Log of Price');

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=353)

# %%
#Prepare a Linear Regression Model
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.5106085039232615

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
regrRM = RandomForestRegressor(n_estimators=100)
regrRM.fit(X_train, y_train)
print(regrRM.score(X_test,y_test))
# Out:
# 0.6311895492843007

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.406222

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn import tree

# %%
regrRM = RandomForestRegressor(n_estimators=500, max_depth = 15)
regrRM.fit(X_train, y_train)
y_pred = regrRM.predict(X_test)
print(regrRM.score(X_test,y_test))
# Out:
# 0.6402753414947945

# %%
regrRM.estimators_
# Out:
# [DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=511591671, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1500344791, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1320051557, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1409842814, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=235251612, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1393714591, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=254470012, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=443376626, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=916789973, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1316138668, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1751469852, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1901858229, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=946559178, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2110460056, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1308777088, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=597354588, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=703663588, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=589195267, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1992900954, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1348068707, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=89182675, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1977923351, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1734373681, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=954948614, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1261405049, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=135359012, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1678877480, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1259216643, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=240119450, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=758264889, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1645358331, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1782393292, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1645709296, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1692120158, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=797660767, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=628834657, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1363644041, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=488803508, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1111142719, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2058696163, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1938813515, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1768867013, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1321902469, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=756142351, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1652513413, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=849928092, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1917608843, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=494248404, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=180407023, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1378285645, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1783253575, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=172957347, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1558529343, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1355677804, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=136375218, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=242583034, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=832510281, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=506563308, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=326316893, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=225708861, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1179108423, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=115057811, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1899269521, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1205180487, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=224697439, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1691774390, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1272679462, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=375616390, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1332345027, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1547831075, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1998208868, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1921524838, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1320598751, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2010658056, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1662357100, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1454432436, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=728247774, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=860012243, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1295514192, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1741921235, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1778594724, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1855409790, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2041317796, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=149611565, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=296540205, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=522704502, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=523395007, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1871222896, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=285659095, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=499619623, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1522977778, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=408413838, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1024767333, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=341323312, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1051277746, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=966914314, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1688578236, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1922218164, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1711200950, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1968188619, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=790509308, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1793499376, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1660453691, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=801385353, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1938959327, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=944270505, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1646439239, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=636161938, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1782725329, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1195919982, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1225720525, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1386704627, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1348359327, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=295479871, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=17421457, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1453895325, splitter='best'),
# ...
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=684964195, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1978181788, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=338989405, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1473886873, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=423229406, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=437535567, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1953337374, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=182546752, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1241962607, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1121050488, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1933106531, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1971773072, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=916559158, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=489185083, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2045238685, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=862717952, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2001860789, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1350251171, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1045971643, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=492918068, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=733115493, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=927288447, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1602423753, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1338721869, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=546444259, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1109502585, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2131502399, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1119505471, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1273081803, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=634838259, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1357468105, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=493412557, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1248106063, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=2010078699, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1424608772, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=290598914, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=581087618, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=1674356566, splitter='best'),
#  DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=15,
#                        max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=907273889, splitter='best')]

# %%
len(regrRM.estimators_)
# Out:
# 500

# %%
plt.figure(figsize=(20,15))
tree.plot_tree(regrRM.estimators_[2],max_depth=2,filled=True,)
## here we set max_depth ==3
# Out:
# [Text(558.0, 713.475, 'X[9] <= 0.25\nmse = 0.334\nsamples = 20323\nvalue = 4.622'),
#  Text(279.0, 509.625, 'X[1] <= 0.531\nmse = 0.166\nsamples = 10043\nvalue = 5.008'),
#  Text(139.5, 305.775, 'X[0] <= 0.434\nmse = 0.134\nsamples = 5041\nvalue = 5.136'),
#  Text(69.75, 101.92499999999995, '\n  (...)  \n'),
#  Text(209.25, 101.92499999999995, '\n  (...)  \n'),
#  Text(418.5, 305.775, 'X[1] <= 0.571\nmse = 0.165\nsamples = 5002\nvalue = 4.879'),
#  Text(348.75, 101.92499999999995, '\n  (...)  \n'),
#  Text(488.25, 101.92499999999995, '\n  (...)  \n'),
#  Text(837.0, 509.625, 'X[1] <= 0.532\nmse = 0.211\nsamples = 10280\nvalue = 4.246'),
#  Text(697.5, 305.775, 'X[0] <= 0.399\nmse = 0.234\nsamples = 3116\nvalue = 4.487'),
#  Text(627.75, 101.92499999999995, '\n  (...)  \n'),
#  Text(767.25, 101.92499999999995, '\n  (...)  \n'),
#  Text(976.5, 305.775, 'X[1] <= 0.574\nmse = 0.165\nsamples = 7164\nvalue = 4.143'),
#  Text(906.75, 101.92499999999995, '\n  (...)  \n'),
#  Text(1046.25, 101.92499999999995, '\n  (...)  \n')]

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.348273

# %% [markdown]
# # jitendra

# %%
import xgboost as xgb

# %%
data_dmatrix = xgb.DMatrix(data=X,label=y)

# %%
xg_reg = xgb.XGBRegressor(objective ='reg:squarederror', colsample_bytree = 0.3, learning_rate = 0.1,
                max_depth = 10, alpha = 2, n_estimators = 500)

# %%
xg_reg.fit(X_train,y_train)
# Out:
# XGBRegressor(alpha=2, base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=10, min_child_weight=1, missing=None, n_estimators=500,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=None, silent=None, subsample=1, verbosity=1)

# %%
xg_reg.score(X_test, y_test)
# Out:
# 0.6348630366268098

# %%
preds = xg_reg.predict(X_test)

# %%
rmse = np.sqrt(mean_squared_error(y_test, preds))
print("RMSE: %f" % (rmse))
# Out:
# RMSE: 0.350884

# %%
r2_score(y_test, preds)
# Out:
# 0.6348630366268098

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

ax = ax.flatten()

temp_df = (pd.DataFrame({"features": X.columns,
                    "feature_importance": regrRM.feature_importances_})
      .sort_values("feature_importance", ascending=False)
      .reset_index(drop=True))

sns.barplot(x="feature_importance",
            y="features",
            data=temp_df,
            orient="h", palette="Blues_d", ax=ax[0])

xgb.plot_importance(xg_reg, importance_type='gain', xlabel='Gain',show_values=False, ax=ax[1])

# %%
score_dict = {'Linear Regression': [reg.score(X_test,y_test)],
              'Random Forest Regression ': [regrRM.score(X_test,y_test)],
              'XGBoost':[xg_reg.score(X_test, y_test)] }

# %%
temp_df = pd.DataFrame.from_dict(score_dict, orient='index').reset_index()
temp_df.columns = ['Model', 'R2-Score']

plot = temp_df['R2-Score'].plot(kind='bar', figsize=(10,4))

plt.xticks([0,1,2], (temp_df['Model']), rotation=0);

plt.margins(x=0.2, y=0.1, tight=True)

for rect in plot.patches:
    height = rect.get_height()
    width = rect.get_width()
    
    x_ = rect.get_x()
    y_ = rect.get_y()
    
    label_text = f'{round(height, 2)}'
    
    label_x = x_ + width - 0.3
    label_y = y_ + height + 0.01
    
    plt.text(label_x, label_y, label_text)

# %%
X = X.drop(['number_of_reviews', 'neighbourhood_group', 'reviews_per_month'], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=353)

# %%
regrRM2 = RandomForestRegressor(n_estimators=500, max_depth = 15)
regrRM2.fit(X_train, y_train)
print(regrRM2.score(X_test, y_test))
# Out:
# 0.633338930316234

# %% [markdown]
# **Observatiions**
# - **After dropping additional Features we can see thst the score is not affected by much**
# - **So we can drop these features if we want to reduce the Model Complexity**

# %%
temp_df = (pd.DataFrame({"features": X.columns,
                    "feature_importance": regrRM2.feature_importances_})
      .sort_values("feature_importance", ascending=False)
      .reset_index(drop=True))

sns.barplot(x="feature_importance",
            y="features",
            data=temp_df,
            orient="h", palette="Blues_d");

# %% [markdown]
# # Conclusions

# %% [markdown]
# - **We get a R2 Score of approximately 0.64 using the Random Forest Regressor and XGBoost**
#
# - **The most important features used to determine the listing prices are**
#
#  1. Room Type
#  2. Longitude
#  3. Latitde
#
# - **We can also reduce the model complexity by further dropping some columns**
